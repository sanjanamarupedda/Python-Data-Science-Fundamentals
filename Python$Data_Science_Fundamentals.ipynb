# %%
#variables
name ='Sanjana'
age =21
cgpa =8
print('Name :',name)
print('Age :',age)
print('CGPA :',cgpa)
#operators
#if -else
marks = 85
if marks>=50:
  print('Pass')
else:
  print('Fail')
#functions
def adds(a,b):
  return a+b
result =adds(10,20)
print('sum:',result)
#list
students =['Sanjana','Shivani','Sahithya']
for student in students:
    print(student)
#dictionary
student ={
    'name':'Sanjana',
    'age':21,
    'course':'Computer Science Enginneering'
}
print(student['name'])
print(student['age'])
print(student['course'])
# file handling
file = open('sample.txt','w')
file.write('Python Data Science Fundamentals')
file.close()
file = open('sample.txt','r')
print(file.read())
file.close()
#Data Science Example
import pandas as pd
data = {
    'name':['Sanjana','Sweety','Shivani','Sahithya'],
    'Marks':[85,89,70,66]
}
df = pd.DataFrame(data)
print(df)
print('Average Marks:', df['Marks'].mean())
# Out:
# Name : Sanjana
# Age : 21
# CGPA : 8
# Pass
# sum: 30
# Sanjana
# Shivani
# Sahithya
# Sanjana
# 21
# Computer Science Enginneering
# Python Data Science Fundamentals
#        name  Marks
# 0   Sanjana     85
# 1    Sweety     89
# 2   Shivani     70
# 3  Sahithya     66
# Average Marks: 77.5
